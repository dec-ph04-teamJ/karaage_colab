# %% [markdown]
# # git hub と colabの連携わかったかも

# %% [markdown]
# # とりあえずnotebook作ってみた

# %% [markdown]
# ## google drive をマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pwd
# Out:
# '/content'

# %% [markdown]
# ## カレントディレクトリを移動

# %%
# %cd /content/drive/MyDrive/dec/ph04/teamJ_python/notebooks/
# Out:
# /content/drive/.shortcut-targets-by-id/1diyN-vG8IJHm4jhskJEnFQAfiTimLiue/teamJ_python/notebooks

# %% [markdown]
# # 1/12 にやったところ

# %%
ACCESS_TOKEN = "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"
REPOSITORY = "harachaan/karaage_colab"  # clone/push したいリポジトリ
USER = "harachaan"
MAIL = "ryuuui.1021@gmail.com"

WORKDIR = "sample"
BRANCH = "develop"

# %%
! git clone https://{USER}:{ACCESS_TOKEN}@github.com/{REPOSITORY}.git {WORKDIR}
# %cd {WORKDIR}
! git config --global user.name {USER}
! git config --global user.email {MAIL}
! git remote set-url origin https://{USER}:{ACCESS_TOKEN}@github.com/{REPOSITORY}.git
# Out:
# Cloning into 'sample'...
# ...
# /content/drive/MyDrive/dec/ph04/teamJ_python/notebooks/sample

# %% [markdown]
# - たぶんここまでで`sample`フォルダとGitHub上の`karaage_colab`がつながった

# %%
# 何してるかわからなかったのでとりあえずコメントアウト
# ! git checkout -b {BRANCH}
# ! git branch

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/dec/ph04/teamJ_python/notebooks/sample'

# %% [markdown]
# この時点ではまだ空のレポジトリなので，GUIでcolabの新たなファイル`hello_git.ipynb`を作成
# で，pushしたい

# %%
! git add .

# %%
! git commit -m "initial commit"
# Out:
# [master (root-commit) 8dfda7a] initial commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 hello_git.ipynb

# %%
! git status
# Out:
# On branch master
# Your branch is based on 'origin/master', but the upstream is gone.
#   (use "git branch --unset-upstream" to fixup)
#
# nothing to commit, working tree clean

# %%
# 上のやつでhttps:の後の//が/一つだけだったから多分反応してなかった．
# ! git remote set-url origin https://{USER}:{ACCESS_TOKEN}@github.com/{REPOSITORY}.git

# %%
! git push origin master
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 688 bytes | 172.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/harachaan/karaage_colab.git
#  * [new branch]      master -> master

# %% [markdown]
# - ここまででとりあえずclone して内容変更して，pushする流れはできた．

# %% [markdown]
# # 1/13

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/dec/ph04/teamJ_python/notebooks'

# %%
# %cd sample
# Out:
# /content/drive/MyDrive/dec/ph04/teamJ_python/notebooks/sample

# %%
! git add .
! git commit -m "second commit"
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@9819ab01ba24.(none)')

# %%
! git config --global user.name {USER}
! git config --global user.email {MAIL}

# %%
! git add .
! git commit -m "second commit"
# Out:
# [master 90abd11] second commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite hello_git.ipynb (74%)

# %%
! git push origin master
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 463 bytes | 115.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/harachaan/karaage_colab.git
#    8dfda7a..90abd11  master -> master

# %% [markdown]
# # 以下，1/10にあがいたところ

# %%
# !git clone https://github.com/harachaan/karaage_colab.git
# Out:
# Cloning into 'karaage_colab'...
# ...

# %% [markdown]
# ## ユーザ名とメールアドレスを設定（これをしないとcommit でエラーになる？）

# %%
# !git config --global user.email "ryuuui.1021@gmail.com"
# !git config --global user.name "hara_windows"

# %%
pwd
# Out:
# '/content/drive/MyDrive/dec/ph04/teamJ_python/notebooks'

# %%
ls
# Out:
# first_colab.ipynb  karaage_colab/

# %%
cd karaage_colab/
# Out:
# [Errno 2] No such file or directory: 'karaage_colab/'
# /content/drive/MyDrive/dec/ph04/teamJ_python/notebooks/karaage_colab

# %%
pwd
# Out:
# '/content/drive/MyDrive/dec/ph04/teamJ_python/notebooks/karaage_colab'

# %%
ls
# Out:
# github_test.ipynb

# %%
# !git add .
# !git commit -m "initial commit"
# Out:
# [master (root-commit) b5920ed] initial commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 github_test.ipynb

# %%
ACCESS_TOKEN = "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"
REPOSITORY = "harachaan/karaage_colab"  # clone/push したいリポジトリ
USER = "harachaan"
MAIL = "ryuuui.1021@gmail.com"

WORKDIR = ""
BRANCH = "develop"

# %%
pwd
# Out:
# '/root'

# %%
! git config --global user.name {USER}
! git config --global user.email {MAIL}
! git remote set-url origin https:/{USER}:{ACCESS_TOKEN}@github.com/{REPOSITORY}.git
! git checkout -b {BRANCH}
! git branch
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-97bb3ce4b232> in <module>
# ----> 1 pwd
#       2 get_ipython().system(' git config --global user.name {USER}')
#       3 get_ipython().system(' git config --global user.email {MAIL}')
#       4 get_ipython().system(' git remote set-url origin https:/{USER}:{ACCESS_TOKEN}@github.com/{REPOSITORY}.git')
#       5 get_ipython().system(' git checkout -b {BRANCH}')
#
# NameError: name 'pwd' is not defined
